# %% [markdown]
# <a href="https://colab.research.google.com/github/jyothishri184/Machine-Learning-Algorithms/blob/main/5_LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Classification
#
# 1.   Binary
# 2.   Multiclass
#
# e = Euler's number ~ 2.71828
#
# Logistic Regression - Sigmoid function - range - 0 to 1
#
# #SIGMOID FUNCTION

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Global and local minima maxima
# Global means it is true for the entire set and local means it is true in some vicinity.
#
# **local minima** - A point on a graph whose value is less than all other points near it.
#
# **global minima** - A global minimum, also known as an absolute minimum, is the smallest over its entire range.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here z = log(odds)
#
# stop at 2nd step from last

# %% [markdown]
# #TYPES OF LOGISTIC REGRESSION
#
#
#
# *   Binary - eg: spam or not a spam
# *   Multinomial - eg:veg / nonveg/ vegan
# *   ordinal - eg: rank 1 to 10, grade A to D

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/logistic_regression/insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
df.shape
# Out:
# (27, 2)

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               27 non-null     int64
#  1   bought_insurance  27 non-null     int64
# dtypes: int64(2)
# memory usage: 560.0 bytes

# %%
df.describe()
# Out:
#              age  bought_insurance
# count  27.000000         27.000000
# mean   39.666667          0.518519
# std    15.745573          0.509175
# min    18.000000          0.000000
# 25%    25.000000          0.000000
# 50%    45.000000          1.000000
# 75%    54.500000          1.000000
# max    62.000000          1.000000

# %%
df.age.nunique()
# Out:
# 24

# %%
df.bought_insurance.nunique()
# Out:
# 2

# %%
df['bought_insurance'].value_counts()
# Out:
# 1    14
# 0    13
# Name: bought_insurance, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 55    2
# 18    2
# 25    2
# 22    1
# 49    1
# 54    1
# 50    1
# 45    1
# 40    1
# 26    1
# 21    1
# 19    1
# 58    1
# 27    1
# 29    1
# 28    1
# 61    1
# 62    1
# 60    1
# 56    1
# 46    1
# 52    1
# 47    1
# 23    1
# Name: age, dtype: int64

# %%
x = df.drop('bought_insurance',axis=1)
x
# Out:
#     age
# 0    22
# 1    25
# 2    47
# 3    52
# 4    46
# 5    56
# 6    55
# 7    60
# 8    62
# 9    61
# 10   18
# 11   28
# 12   27
# 13   29
# 14   49
# 15   55
# 16   25
# 17   58
# 18   19
# 19   18
# 20   21
# 21   26
# 22   40
# 23   45
# 24   50
# 25   54
# 26   23

# %%
y = df.drop('age',axis=1)
y
# Out:
#     bought_insurance
# 0                  0
# 1                  0
# 2                  1
# 3                  0
# 4                  1
# 5                  1
# 6                  0
# 7                  1
# 8                  1
# 9                  1
# 10                 0
# 11                 0
# 12                 0
# 13                 0
# 14                 1
# 15                 1
# 16                 1
# 17                 1
# 18                 0
# 19                 0
# 20                 0
# 21                 0
# 22                 1
# 23                 1
# 24                 1
# 25                 1
# 26                 0

# %%
model = LogisticRegression()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (21, 1)

# %%
x_test.shape
# Out:
# (6, 1)

# %%
model.fit(x_train,y_train) #model training
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred = model.predict(x_test)
print(f'{y_test}-{y_pred}')
# Out:
#     bought_insurance
# 8                  1
# 13                 0
# 9                  1
# 21                 0
# 0                  0
# 11                 0-[1 0 1 0 0 0]

# %%
from sklearn.metrics import accuracy_score
print(f'ACCURACY: {accuracy_score(y_test,y_pred)}')
# Out:
# ACCURACY: 1.0

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
model.score(x_train,y_train)
# Out:
# 0.8571428571428571
